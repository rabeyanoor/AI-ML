# %%
import numpy as np

# %%
data=np.array([45, 48, 50, 52, 55, 58, 60, 62, 65, 68,70, 72, 75, 78, 80, 85, 90, 95, 150, 500])

data
# Out:
# array([ 45,  48,  50,  52,  55,  58,  60,  62,  65,  68,  70,  72,  75,
#         78,  80,  85,  90,  95, 150, 500])

# %%
# range
data_range =np.max(data)-np.min(data)
data_range
# Out:
# 455

# %%
# variance(population)

variance=np.var(data)
variance.round(2)
# Out:
# 9232.49

# %%
# standard deviation

std_dev=np.std(data)
x=std_dev.round(2)
print("Standard Deviation:", x)
# Out:
# Standard Deviation: 96.09

# %%
# Q2 (Median)
q2= np.median(data)
q2
# Out:
# 69.0

# %%
q1=np.percentile(data,25)
q3=np.percentile(data,75)

iqr=q3-q1
print("Q1:",q1)
print("Q3:",q3)
print("IQR:", iqr)
# Out:
# Q1: 57.25
# Q3: 81.25
# IQR: 24.0

# %%
lower_fence=q1-1.5*iqr
upper_fence=q3+1.5*iqr

print("Lower Fence:", lower_fence)
print("Upper Fence:", upper_fence)
# Out:
# Lower Fence: 21.25
# Upper Fence: 117.25

# %%
outliers=data[(data<lower_fence) | (data>upper_fence)]


print("Outliers:",outliers)
print("Number of Outliers:", len(outliers))
# Out:
# Outliers: [150 500]
# Number of Outliers: 2
