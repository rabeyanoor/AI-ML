# %% [markdown]
# ### Class , object and instance

# %%
class Dog():
    pass

dog1=Dog()
dir(dog1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Dog():
    pass

dog1=Dog()
dog1.name='ABC'
dog1.age=20
print(dog1.name)
print(dog1.age)
# Out:
# ABC
# 20

# %%
class Dog():
    def __init__(self):
      print("call holo")

    def speak():
       print("Dog speaking")

dog1=Dog()
# Out:
# call holo

# %%
class Dog():
    # constructor
    def __init__(self,name,age):
      self.name=name
      self.age=age
      


dog1=Dog('ABC',20)
print(dog1.name,dog1.age)
# Out:
# ABC 20

# %%
class Dog():
    # constructor
    def __init__(self,name,age):
      self.name=name
      self.age=age
      


dog1=Dog('ABC',20)
print(dog1.name,dog1.age)

dog2=Dog('ABC2',40)
print(dog2.name,dog2.age)
# Out:
# ABC 20
# ABC2 40

# %%
class Dog():
    # constructor
    def __init__(self,name,age):
      self.name=name
      self.age=age
      


dog1=Dog('ABC',20)
# print(dog1.name,dog1.age)

dog2=Dog('ABC2',40)
# print(dog2.name,dog2.age)

dir(dog1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):
      self.name=name # instance attribute
      self.age=age # instance attribute
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

print(dog1.name)
print(dog1.food)
print(dog2.food)
# Out:
# ABC
# Rabeya
# Rabeya

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):
      self.name=name # instance attribute
      self.age=age # instance attribute

    # instance method
    def speak(self):
       print("Dog speaking",{self.name})    
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

dog1.speak()
dog2.speak()
# Out:
# Dog speaking {'ABC'}
# Dog speaking {'ABC2'}

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):
      self.name=name # instance attribute
      self.age=age # instance attribute

    # instance method
    def speak(self):
       print("Dog speaking")   
   # instance method
    def info(self):
       print("Food",self.food)    
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

dog1.info()
# Out:
# Food Rabeya

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):   # jkono name deo jabe cls , self, .....    
      self.name=name # instance attribute
      self.age=age # instance attribute

    # instance method
    def speak(self):  # instance method all attribute axcess nite parbe 
       print("Dog speaking",{self.name})   

    @ classmethod  # class method only class attribute gulo axcess korte parbe 
    def info(cls):
       print("Food", cls.food) # jkono name deo jabe cls , self, .....    
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

dog1.info()
# Out:
# Food Rabeya

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):   # jkono name deo jabe cls , self, .....    
      self.name=name # instance attribute
      self.age=age # instance attribute

    # instance method
    def speak(self):  # instance method all attribute axcess nite parbe 
       print("Dog speaking",{self.name},{self.age},{self.food})   

    @ classmethod  # class method only class attribute gulo axcess korte parbe 
    def info(cls):
       print("Food", cls.food) # jkono name deo jabe cls , self, .....    
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

dog1.speak()
# Out:
# Dog speaking {'ABC'} {20} {'Rabeya'}

# %%
class Dog():
    food="Rabeya" # class attribute
    # constructor
    def __init__(self,name,age):
      self.name=name # instance attribute
      self.age=age # instance attribute

    # instance method
    def speak(self):
       print("Dog speaking",{self.name},{self.food})   

    # @ classmethod
    # def info(self):
    #    print("Food",self.food)    
      
dog1=Dog('ABC',20)
dog2=Dog('ABC2',40)

dog1.speak()
# Out:
# Dog speaking {'ABC'} {'Rabeya'}

# %% [markdown]
# ### Inheritance

# %%
## Inherit (single inheritance)
## Parent Class / Base class / Super class
class Car:
  def __init__(self, windows, door, enginetype) -> None:
     self.windows = windows
     self.door = door
     self.enginetype = enginetype


  def drive(self):
    print(f"The person will drive the {self.enginetype} card")

# %%
# Derived/Child/ Subclass

class Tesla(Car):
    def __init__(self,windows,door,enginetype, is_selfDriving):
        super().__init__(windows,door,enginetype)
        self.is_selfDriving= is_selfDriving

teslal= Tesla(4,4,"AB",True)
print(teslal.windows)
# Out:
# 4

# %%
## Multiple Inheritance
## When a class inherits from more than one base class

## Base class 1
class Animal:
  def __init__(self, name) -> None:
    self.name = name

  def eat(self):
    print(f"{self.name} is eating from Animal Base Class")

## Base class 2
class Pet:
  def __init__(self, owner) -> None:
     self.owner = owner


# Derive class
class Dog(Animal, Pet):
  def __init__(self, name, owner) -> None:
    Animal.__init__(self, name)
    Pet.__init__(self, owner)


dog1 = Dog("ABC", "DEF")
dir(dog1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'eat',
#  'name',
#  'owner']

# %% [markdown]
# ### Polymorphism

# %%
## Base Class

class Animal:
    def speak(self):
        return "Sound of the animal"
    
# Derived Class 1
class  Dog (Animal):
    def speak(self):
        return "Woof!"
    
## Derived class 2
class Cat(Animal):
    def speak(self):
        return "Meow!"

cat1 = Cat()
print(cat1.speak())
dir(cat1)
# Out:
# Meow!
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'speak']

# %% [markdown]
# ### Encapsulation

# %%
# Encapsulation  with Getter and Setter MEthods

# Public,protected,private variables or access modifiers

class Person:
    def __init__(self,name,age, balance):
        self.name=name    ## public variables
        self.age=age      ## public variables
        self.balance = balance


def get_name(person):
    return person.name

person1 = Person("Rakib", 20, 10000)
print(person1.balance)

person1.name
# Out:
# 10000
# 'Rakib'

# %%
# Getter and Setter MEthods
class Person:
    def __init__(self,name,age, balance):
        self.name=name    ## public variables
        self._age=age      ## protected variables -> Child class access
        self.__balance = balance ## private -> only nijer class

    def info(self):
      print("Balance ", self.__balance)

    def get_balance(self):
        return self.__balance

    def set_balance(self, money):
        self.__balance += money

# bayrer method
def get_name(person):
    return person.name

person1 = Person("Rakib", 20, 10000)
person1.set_balance(500)
print(person1.name)
print(person1.get_balance())
# Out:
# Rakib
# 10500

# %% [markdown]
# ### Abstraction
