# %% [markdown]
# # Pandas Basic

# %%
import pandas as pd

# %%
data=[10,20,30,40]
sr=pd.Series(data)
sr
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
data={'a':10,'b':20,'c':30,'d':40}
sr=pd.Series(data)
print(sr)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = [10,20,30,40]
sr = pd.Series(data, index=['x','y','z','zz'])
print(sr)
print(sr.loc['x'])
print(sr.iloc[0])
# Out:
# x     10
# y     20
# z     30
# zz    40
# dtype: int64
# 10
# 10

# %%
print(sr['x'])
# Out:
# 10

# %%
data = {'a': 10, 'b':20, 'c': 30}
sr = pd.Series(data)
sr
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(sr['a']) # index=0
print(sr[1])
print(sr[['a', 'c']])
# Out:
# 10
# 20
# a    10
# c    30
# dtype: int64
# /tmp/ipykernel_61963/1420681834.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(sr[1])

# %%
print(sr.loc[['a', 'c']])
print(sr.loc['a']) # level a,b or x,y agulodea thakle loc hobe. r jodi index deo thake thahole (iloc ) hobe i--> index
# Out:
# a    10
# c    30
# dtype: int64
# 10

# %%
print(sr.iloc[1])
# Out:
# 20

# %%
sr
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(sr['x':'z']) # loc = Last tao nibe
print(sr[0:2]) # iloc = Last er ager ta porjonto nibe
# Out:
# Series([], dtype: int64)
# a    10
# b    20
# dtype: int64

# %%
print(sr.loc['x':'z'])
# Out:
# x    10
# y    20
# z    30
# dtype: int64

# %%
print(sr.loc['x':'z'])
print(sr.iloc[0:2])
# Out:
# x    10
# y    20
# z    30
# dtype: int64
# x    10
# y    20
# dtype: int64

# %%
print(sr.get('x'))
print(sr.get('a')) # a name kicu nai x ace. tai a= None hoise
# Out:
# 10
# None

# %%
print(sr.get('a',50))
# Out:
# 50

# %%
## Dataframe
series1 = pd.Series([10,20,30,40], index=[2, 3,4,5])
series2 = pd.Series(['A','B','C','D'], index=[5, 4, 3, 2])

df = pd.DataFrame({'Numbers': series1, 'Letter':series2})
df
# Out:
#    Numbers Letter
# 2       10      D
# 3       20      C
# 4       30      B
# 5       40      A

# %%
## Dataframe
series1 = pd.Series([10,20,30,40], index=[2, 3,4,5])
series2 = pd.Series(['A','B','C','D'], index=[4, 3, 5, 2])

df = pd.DataFrame({'Numbers': series1, 'Letter':series2})
df
# Out:
#    Numbers Letter
# 2       10      D
# 3       20      B
# 4       30      A
# 5       40      C

# %%
## Dataframa 2 Dictionary of list

data1 = {
    'Name': ['Rakib', 'Tamim', 'Yasin'],
    'Age': [25, 24, 27],
    'City': ['Chittagong', 'Dhaka', 'Barishal']
}
df = pd.DataFrame(data1)
df

# create column
# Out:
#     Name  Age        City
# 0  Rakib   25  Chittagong
# 1  Tamim   24       Dhaka
# 2  Yasin   27    Barishal

# %%
## Dataframa 3 List of dictionary
data3 = [
    {'Name': 'Rakib', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib2', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib3', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib3', 'Age': 25, 'City': "Chittagong"},
]
df2 = pd.DataFrame(data3)
df2
# Out:
#      Name  Age        City
# 0   Rakib   25  Chittagong
# 1  Rakib2   25  Chittagong
# 2  Rakib3   25  Chittagong
# 3  Rakib3   25  Chittagong

# %%
## Dataframa 3 List of dictionary
data3 = [
    {'Name': 'Rakib', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib2', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib3', 'Age': 25, 'City': "Chittagong"},
    {'Name': 'Rakib3', 'Age': 25, 'City': "Chittagong"},
]
df2 = pd.DataFrame(data3, index=['a','b','c','d'])
df2

# create row
# Out:
#      Name  Age        City
# a   Rakib   25  Chittagong
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong
# d  Rakib3   25  Chittagong

# %%
print(df2.loc['a'])
# Out:
# Name         Rakib
# Age             25
# City    Chittagong
# Name: a, dtype: object

# %%
print(df2.iloc[1])
# Out:
# Name        Rakib2
# Age             25
# City    Chittagong
# Name: b, dtype: object

# %%
print(df2.iloc[0:3])
# Out:
#      Name  Age        City
# a   Rakib   25  Chittagong
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong

# %%
print(df2.loc['a':'c'])
# Out:
#      Name  Age        City
# a   Rakib   25  Chittagong
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong

# %%
print(df2.iat[1,0])
# Out:
# Rakib2

# %%
## Add a Column
df2['Salary']=[1000,2500,5000,4500]
df2
# Out:
#      Name  Age        City  Salary
# a   Rakib   25  Chittagong    1000
# b  Rakib2   25  Chittagong    2500
# c  Rakib3   25  Chittagong    5000
# d  Rakib3   25  Chittagong    4500

# %%
df2['Salary']
# Out:
# a    1000
# b    2500
# c    5000
# d    4500
# Name: Salary, dtype: int64

# %%
df2
# Out:
#      Name  Age        City  Salary
# a   Rakib   25  Chittagong    1000
# b  Rakib2   25  Chittagong    2500
# c  Rakib3   25  Chittagong    5000
# d  Rakib3   25  Chittagong    4500

# %% [markdown]
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
# columns (1 or 'columns').

# %%
df2.drop('Salary', axis=1)
df2
# Out:
#      Name  Age        City  Salary
# a   Rakib   25  Chittagong    1000
# b  Rakib2   25  Chittagong    2500
# c  Rakib3   25  Chittagong    5000
# d  Rakib3   25  Chittagong    4500

# %%
df2.drop('Salary', axis=1, inplace=True)
df2
# Out:
#      Name  Age        City
# a   Rakib   25  Chittagong
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong
# d  Rakib3   25  Chittagong

# %%
df2.drop('a', axis=0)
# Out:
#      Name  Age        City
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong
# d  Rakib3   25  Chittagong

# %%
df2
# Out:
#      Name  Age        City
# a   Rakib   25  Chittagong
# b  Rakib2   25  Chittagong
# c  Rakib3   25  Chittagong
# d  Rakib3   25  Chittagong

# %%
df2['Age'] = df2['Age']+10

# %%
df2
# Out:
#      Name  Age        City
# a   Rakib   55  Chittagong
# b  Rakib2   55  Chittagong
# c  Rakib3   55  Chittagong
# d  Rakib3   55  Chittagong

# %% [markdown]
# # Read from csv

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# ...

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.tail()
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
df.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df.fillna(0)
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %%
df['Sales_NOT_NAN'] = df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#           Date Category  Value   Product  Sales Region  Sales_NOT_NAN
# 0   2023-01-01        A   28.0  Product1  754.0   East     754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North     110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East     398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East     522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North     869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West     192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East     936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West     488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West     772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West     834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North     842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West     557.130435
# ...

# %%
df = df.rename(columns={'Sales_NOT_NAN':'New_Sales'})
df
# Out:
#           Date Category  Value   Product  Sales Region   New_Sales
# 0   2023-01-01        A   28.0  Product1  754.0   East  754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North  110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East  398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East  522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North  869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West  192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East  936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West  488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West  772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West  834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North  842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West  557.130435
# 12  2023-01-13        A   70.0  Product3  628.0  South  628.000000
# ...

# %%
df['Value_2x']= df['Value'].apply(lambda x: x*2)
df
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 0   2023-01-01        A   28.0  Product1  754.0   East      56.0
# 1   2023-01-02        B   39.0  Product3  110.0  North      78.0
# 2   2023-01-03        C   32.0  Product2  398.0   East      64.0
# 3   2023-01-04        B    8.0  Product1  522.0   East      16.0
# 4   2023-01-05        B   26.0  Product3  869.0  North      52.0
# 5   2023-01-06        B   54.0  Product3  192.0   West     108.0
# 6   2023-01-07        A   16.0  Product1  936.0   East      32.0
# 7   2023-01-08        C   89.0  Product1  488.0   West     178.0
# 8   2023-01-09        C   37.0  Product3  772.0   West      74.0
# 9   2023-01-10        A   22.0  Product2  834.0   West      44.0
# 10  2023-01-11        B    7.0  Product1  842.0  North      14.0
# 11  2023-01-12        B   60.0  Product2    NaN   West     120.0
# 12  2023-01-13        A   70.0  Product3  628.0  South     140.0
# ...

# %%
df=df.sort_values(['Value_2x']) # first a df na dile sort hobe na
df
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 37  2023-02-07        C    2.0  Product1    NaN  North       4.0
# 46  2023-02-16        B    6.0  Product1  938.0  South      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East      16.0
# 49  2023-02-19        C   11.0  Product3  708.0  North      22.0
# 40  2023-02-10        B   15.0  Product1  578.0   East      30.0
# 6   2023-01-07        A   16.0  Product1  936.0   East      32.0
# 31  2023-02-01        A   17.0  Product2  189.0   West      34.0
# 9   2023-01-10        A   22.0  Product2  834.0   West      44.0
# 24  2023-01-25        A   24.0  Product2  458.0   East      48.0
# 4   2023-01-05        B   26.0  Product3  869.0  North      52.0
# 33  2023-02-03        C   27.0  Product3    NaN   East      54.0
# 0   2023-01-01        A   28.0  Product1  754.0   East      56.0
# ...

# %%
df = df.sort_values(['Value_2x', 'Sales'], ascending=True)
df
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 37  2023-02-07        C    2.0  Product1    NaN  North       4.0
# 46  2023-02-16        B    6.0  Product1  938.0  South      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East      16.0
# 49  2023-02-19        C   11.0  Product3  708.0  North      22.0
# 40  2023-02-10        B   15.0  Product1  578.0   East      30.0
# 6   2023-01-07        A   16.0  Product1  936.0   East      32.0
# 31  2023-02-01        A   17.0  Product2  189.0   West      34.0
# 9   2023-01-10        A   22.0  Product2  834.0   West      44.0
# 24  2023-01-25        A   24.0  Product2  458.0   East      48.0
# 4   2023-01-05        B   26.0  Product3  869.0  North      52.0
# 33  2023-02-03        C   27.0  Product3    NaN   East      54.0
# 0   2023-01-01        A   28.0  Product1  754.0   East      56.0
# ...

# %%
df[ (df['Category']=='A') ]
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 6   2023-01-07        A   16.0  Product1  936.0   East      32.0
# 31  2023-02-01        A   17.0  Product2  189.0   West      34.0
# 9   2023-01-10        A   22.0  Product2  834.0   West      44.0
# 24  2023-01-25        A   24.0  Product2  458.0   East      48.0
# 0   2023-01-01        A   28.0  Product1  754.0   East      56.0
# 18  2023-01-19        A   31.0  Product2  578.0   West      62.0
# 43  2023-02-13        A   43.0  Product3  949.0   East      86.0
# 14  2023-01-15        A   47.0  Product2  893.0   West      94.0
# 19  2023-01-20        A   59.0  Product1  736.0   East     118.0
# 39  2023-02-09        A   62.0  Product1  155.0   West     124.0
# 13  2023-01-14        A   69.0  Product1  423.0   East     138.0
# 12  2023-01-13        A   70.0  Product3  628.0  South     140.0
# 42  2023-02-12        A   93.0  Product3  164.0   West     186.0
# ...

# %%
df[ (df['Category']=='A') & (df['Region']=='East')]
# Out:
#           Date Category  Value   Product  Sales Region  New_Sales  Value_2x
# 6   2023-01-07        A   16.0  Product1  936.0   East      936.0      32.0
# 24  2023-01-25        A   24.0  Product2  458.0   East      458.0      48.0
# 0   2023-01-01        A   28.0  Product1  754.0   East      754.0      56.0
# 43  2023-02-13        A   43.0  Product3  949.0   East      949.0      86.0
# 19  2023-01-20        A   59.0  Product1  736.0   East      736.0     118.0
# 13  2023-01-14        A   69.0  Product1  423.0   East      423.0     138.0
# 44  2023-02-14        A   96.0  Product3  830.0   East      830.0     192.0

# %%
df[ ~(df['Category']=='A')] # (~) --> not . mane A bade sob
# Out:
#           Date Category  Value   Product  Sales Region   New_Sales  Value_2x
# 37  2023-02-07        C    2.0  Product1    NaN  North  557.130435       4.0
# 46  2023-02-16        B    6.0  Product1  938.0  South  938.000000      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North  842.000000      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East  522.000000      16.0
# 49  2023-02-19        C   11.0  Product3  708.0  North  708.000000      22.0
# 40  2023-02-10        B   15.0  Product1  578.0   East  578.000000      30.0
# 4   2023-01-05        B   26.0  Product3  869.0  North  869.000000      52.0
# 33  2023-02-03        C   27.0  Product3    NaN   East  557.130435      54.0
# 2   2023-01-03        C   32.0  Product2  398.0   East  398.000000      64.0
# 36  2023-02-06        C   36.0  Product3  177.0   East  177.000000      72.0
# 8   2023-01-09        C   37.0  Product3  772.0   West  772.000000      74.0
# ...

# %%
arr = df[ df['Category']=='B']
print(arr)
print(type(arr)) # DataFrame
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 46  2023-02-16        B    6.0  Product1  938.0  South      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East      16.0
# 40  2023-02-10        B   15.0  Product1  578.0   East      30.0
# 4   2023-01-05        B   26.0  Product3  869.0  North      52.0
# 1   2023-01-02        B   39.0  Product3  110.0  North      78.0
# 30  2023-01-31        B   50.0  Product3  735.0   West     100.0
# 5   2023-01-06        B   54.0  Product3  192.0   West     108.0
# 11  2023-01-12        B   60.0  Product2    NaN   West     120.0
# 35  2023-02-05        B   60.0  Product2    NaN   West     120.0
# 22  2023-01-23        B   62.0  Product3  942.0  North     124.0
# 32  2023-02-02        B   63.0  Product3  338.0  South     126.0
# 47  2023-02-17        B   69.0  Product3  143.0   West     138.0
# ...

# %%
arr = arr['Value'].unique()
print(arr)
print(type(arr)) # age DataFrame cilo . akhon convert hoe numpy.ndarray te hoe gece
# Out:
# [ 6.  7.  8. 15. 26. 39. 50. 54. 60. 62. 63. 69. 99. nan]
# <class 'numpy.ndarray'>

# %%
arr = df[ df['Category']=='B']
arr.drop_duplicates()
# Out:
#           Date Category  Value   Product  Sales Region  Value_2x
# 46  2023-02-16        B    6.0  Product1  938.0  South      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East      16.0
# 40  2023-02-10        B   15.0  Product1  578.0   East      30.0
# 4   2023-01-05        B   26.0  Product3  869.0  North      52.0
# 1   2023-01-02        B   39.0  Product3  110.0  North      78.0
# 30  2023-01-31        B   50.0  Product3  735.0   West     100.0
# 5   2023-01-06        B   54.0  Product3  192.0   West     108.0
# 11  2023-01-12        B   60.0  Product2    NaN   West     120.0
# 35  2023-02-05        B   60.0  Product2    NaN   West     120.0
# 22  2023-01-23        B   62.0  Product3  942.0  North     124.0
# 32  2023-02-02        B   63.0  Product3  338.0  South     126.0
# 47  2023-02-17        B   69.0  Product3  143.0   West     138.0
# ...

# %%
arr = df[ df['Category']=='B']
arr.drop_duplicates(subset=['Value']) # value er modhe duplicate gulo bad jabe
# Out:
#           Date Category  Value   Product  Sales Region   New_Sales  Value_2x
# 46  2023-02-16        B    6.0  Product1  938.0  South  938.000000      12.0
# 10  2023-01-11        B    7.0  Product1  842.0  North  842.000000      14.0
# 3   2023-01-04        B    8.0  Product1  522.0   East  522.000000      16.0
# 40  2023-02-10        B   15.0  Product1  578.0   East  578.000000      30.0
# 4   2023-01-05        B   26.0  Product3  869.0  North  869.000000      52.0
# 1   2023-01-02        B   39.0  Product3  110.0  North  110.000000      78.0
# 30  2023-01-31        B   50.0  Product3  735.0   West  735.000000     100.0
# 5   2023-01-06        B   54.0  Product3  192.0   West  192.000000     108.0
# 35  2023-02-05        B   60.0  Product2    NaN   West  557.130435     120.0
# 22  2023-01-23        B   62.0  Product3  942.0  North  942.000000     124.0
# 32  2023-02-02        B   63.0  Product3  338.0  South  338.000000     126.0
# ...

# %% [markdown]
# # Problem Solving (LeetCode)

# %% [markdown]
# https://leetcode.com/problems/customers-who-never-order/description/?envType=study-plan-v2&envId=30-days-of-pandas&lang=pythondata

# %%
import pandas as pd

def find_customers(customers: pd.DataFrame, orders: pd.DataFrame) -> pd.DataFrame:
    arr = customers[ ~customers['id'].isin(orders['customerId'])]
    arr2 = arr[['name']].rename(columns={'name':'Customers'})
    return arr2

# %% [markdown]
# https://leetcode.com/problems/article-views-i/?envType=study-plan-v2&envId=30-days-of-pandas&lang=pythondata

# %%
import pandas as pd

def article_views(views: pd.DataFrame) -> pd.DataFrame:
    arr = views[ views['author_id']==views['viewer_id']  ]

    arr2 = arr['author_id'].unique()
    arr2 = sorted(arr2)

    return pd.DataFrame({'id':arr2})
