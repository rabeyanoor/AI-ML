# %%
# %pip install torch torchvision torchaudio --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/rabeya-noor/.local/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: torchvision in /home/rabeya-noor/.local/lib/python3.12/site-packages (0.25.0)
# Requirement already satisfied: torchaudio in /home/rabeya-noor/.local/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: filelock in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from torch) (68.1.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch) (1.3.3)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision) (10.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)

# %%
# %pip install torch torchvision torchaudio tensorflow --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/rabeya-noor/.local/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: torchvision in /home/rabeya-noor/.local/lib/python3.12/site-packages (0.25.0)
# Requirement already satisfied: torchaudio in /home/rabeya-noor/.local/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: tensorflow in /home/rabeya-noor/.local/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: filelock in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from torch) (68.1.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (2026.1.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch) (1.3.3)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/lib/python3/dist-packages (from torchvision) (10.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorflow) (2.31.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.42.0)
# Requirement already satisfied: rich in /usr/lib/python3/dist-packages (from keras>=3.10.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/rabeya-noor/.local/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/rabeya-noor/.local/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/rabeya-noor/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/lib/python3/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/lib/python3/dist-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# r = distance from the center (radius)
# θ = angle from the horizontal axis

def generate_spiral(n, noise=0.2): #Without noise → all points lie exactly on the spiral
    theta = np.sqrt(np.random.rand(n)) * 2 * np.pi #angel of the spiral
    r = 2 * theta  #radius (distance from the center)
    x1 = r * np.cos(theta) + noise * np.random.randn(n) #x-coordinate of each point in the spiral
    x2 = r * np.sin(theta) + noise * np.random.randn(n) #r * np.sin(theta) → convert polar to Cartesian
    return np.c_[x1, x2] #column stack

X0 = generate_spiral(500) #first spiral
X1 = -generate_spiral(500) #flipped another spiral

X = np.vstack([X0, X1])
y = np.array([0]*500 + [1]*500)

# %%
import matplotlib.pyplot as plt
import numpy as np


# Visualize the spirals
plt.figure(figsize=(6,6))
plt.scatter(X[y==0][:,0], X[y==0][:,1], color='red', label='Class 0')
plt.scatter(X[y==1][:,0], X[y==1][:,1], color='blue', label='Class 1')

plt.title("Spiral Dataset")

plt.xlabel("x1")
plt.ylabel("x2")
plt.legend()
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)


ml_model = LogisticRegression()
ml_model.fit(X_train, y_train)

print("ML Train Accuracy:", ml_model.score(X_train, y_train))
print("ML Test Accuracy :", ml_model.score(X_test, y_test))
# Out:
# ML Train Accuracy: 0.74875
# ML Test Accuracy : 0.78

# %% [markdown]
# #DL Model

# %%
dl_model = Sequential([
    Dense(256, activation='relu', input_shape=(2,)),
    Dense(256, activation='relu'),
    Dense(1, activation='sigmoid')
])

dl_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

dl_model.fit(X_train, y_train, epochs=50, verbose=0)

train_loss, train_acc = dl_model.evaluate(X_train, y_train, verbose=0)
test_loss, test_acc = dl_model.evaluate(X_test, y_test, verbose=0)

print("DL Train Accuracy:", train_acc)
print("DL Test Accuracy :", test_acc)
# Out:
# /home/rabeya-noor/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# DL Train Accuracy: 1.0
# DL Test Accuracy : 1.0
